# %% [markdown]
# <a href="https://colab.research.google.com/github/kangtayie/Machine-Learning_class/blob/main/EX1_iris(0914).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/iris.csv")

# %%
X = df.drop("species", axis=1)

y = df["species"]

# %%
X
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             1.9
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = DecisionTreeClassifier()

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = model.predict(X_test)

print(classification_report(y_test, pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         9
#   versicolor       0.83      0.83      0.83        12
#    virginica       0.78      0.78      0.78         9
#
#     accuracy                           0.87        30
#    macro avg       0.87      0.87      0.87        30
# weighted avg       0.87      0.87      0.87        30

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier()
model_rf.fit(X_train, y_train)

pred_rf = model_rf.predict(X_test)
print("--- Random Forest 결과 ---")
print(classification_report(y_test, pred_rf))
# Out:
# --- Random Forest 결과 ---
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         9
#   versicolor       0.83      0.83      0.83        12
#    virginica       0.78      0.78      0.78         9
#
#     accuracy                           0.87        30
#    macro avg       0.87      0.87      0.87        30
# weighted avg       0.87      0.87      0.87        30

# %%
from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression(max_iter=200)
model_lr.fit(X_train, y_train)

pred_lr = model_lr.predict(X_test)
print("--- Logistic Regression 결과 ---")
print(classification_report(y_test, pred_lr))
# Out:
# --- Logistic Regression 결과 ---
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         9
#   versicolor       1.00      0.83      0.91        12
#    virginica       0.82      1.00      0.90         9
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.94      0.94        30
# weighted avg       0.95      0.93      0.93        30

# %%
from sklearn.neighbors import KNeighborsClassifier

model_knn = KNeighborsClassifier()
model_knn.fit(X_train, y_train)

pred_knn = model_knn.predict(X_test)
print("--- KNN 결과 ---")
print(classification_report(y_test, pred_knn))
# Out:
# --- KNN 결과 ---
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         9
#   versicolor       1.00      0.83      0.91        12
#    virginica       0.82      1.00      0.90         9
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.94      0.94        30
# weighted avg       0.95      0.93      0.93        30

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# 데이터 로드
df_iris = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/iris.csv")

# 시각화 설정
plt.figure(figsize=(6, 4))
sns.countplot(x="species", data=df_iris, palette="viridis")

# 제목 및 라벨 설정
plt.title("Iris Dataset - Class Distribution (Species)")
plt.xlabel("Species")
plt.ylabel("Count")

# 그래프 출력
plt.show()
# Out:
# /tmp/ipykernel_1374/1010754179.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="species", data=df_iris, palette="viridis")
